# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import time

# %%
# %cd ..
# Out:
# d:\DEV\SouJunior\Personal Lab
# C:\Users\Moscarde\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
class LinkedInScraper:
    def __init__(self, login, password, headless = False):

        self.driver = self.initialize_driver(headless)
        self.login_linkedin = login
        self.password_linkedin = password

    def initialize_driver(self, headless):
        options = Options()
        options.headless = headless
        return webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    def login(self):
        url = "https://www.linkedin.com/login/pt"
        self.driver.get(url)

        xpath_login = '//*[@id="username"]'
        xpath_password = '//*[@id="password"]'
        xpath_submit = '//*[@id="organic-div"]/form/div[3]/button'

        input_login = WebDriverWait(self.driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, xpath_login))
        )
        input_password = WebDriverWait(self.driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, xpath_password))
        )
        input_submit = WebDriverWait(self.driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, xpath_submit))
        )

        input_login.clear()
        input_password.clear()

        input_login.send_keys(self.login_linkedin)
        input_password.send_keys(self.password_linkedin)
        input_submit.click()

        if WebDriverWait(self.driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, '//*[@id="global-nav"]'))
        ):
            print("Login successful")
        else:
            print("Login failed")

    def navigate_to_posts(self):
        linkedin_page_url = (
            "https://www.linkedin.com/company/soujunior/posts/?feedView=all"
        )
        self.driver.get(linkedin_page_url)

    def sort_by_date(self):
        class_sort = "sort-dropdown__dropdown"
        sort_div = WebDriverWait(self.driver, 10).until(
            EC.element_to_be_clickable((By.CLASS_NAME, class_sort))
        )
        sort_button = sort_div.find_element(By.TAG_NAME, "button")
        sort_button.click()

        time.sleep(1)
        sort_by_date = sort_div.find_elements(By.TAG_NAME, "li")[1]
        sort_by_date.click()

        time.sleep(2)

    def scroll_to_load_posts(self, scrolls=5):
        body = self.driver.find_element(By.TAG_NAME, "body")
        for _ in range(scrolls):
            body.send_keys(Keys.PAGE_DOWN)
            time.sleep(2)

    def collect_posts(self):
        class_feed_posts = "scaffold-finite-scroll__content"
        feed_posts = self.driver.find_element(By.CLASS_NAME, class_feed_posts)
        return feed_posts.find_elements(By.XPATH, "./div")

    def scrape_posts(self):
        posts = self.collect_posts()

        output_folder = "data"
        screenshoted_author_list = [
            file.split(".png")[0]
            for file in os.listdir("linkedin_page\dataframes\profile_pics")
        ]
        new_posts = []

        for post in posts:
            author = post.find_elements(By.CLASS_NAME, "update-components-actor__name")

            if author:
                author_name = (
                    author[0].find_element(By.CLASS_NAME, "visually-hidden").text
                )
            else:
                continue

            if author_name not in screenshoted_author_list:
                img = post.find_element(
                    By.CLASS_NAME, "update-components-actor__avatar-image"
                )
                img_path = f"linkedin_page\dataframes\profile_pics/{author_name}.png"
                img.screenshot(img_path)
                screenshoted_author_list.append(author_name)

            new_posts.append(
                BeautifulSoup(post.get_attribute("outerHTML"), "html.parser")
            )

        return new_posts

    def stage_data(self, data):
        # delete old data
        for file in os.listdir("linkedin_page/staged_data"):
            os.remove(f"linkedin_page/staged_data/{file}")
        # save post
        for index, post in enumerate(data, 1):
            with open(
                f"linkedin_page/staged_data/post_{index}.html", "w", encoding="utf-8"
            ) as file:
                file.write(str(post))

# %%
load_dotenv()

login_linkedin = os.environ["LOGIN_LINKEDIN"]
password_linkedin = os.environ["PASSWORD_LINKEDIN"]

scraper = LinkedInScraper(login_linkedin, password_linkedin, headless=False)
scraper.login()
scraper.navigate_to_posts()
scraper.sort_by_date()
scraper.scroll_to_load_posts()

new_posts = scraper.scrape_posts()
scraper.stage_data(new_posts)
new_posts
# Out:
# Login successful
# [<div>
#  <div class="ember-view occludable-update" id="ember435">
#  <div class="full-height">
#  <div class="full-height">
#  <div class="feed-shared-update-v2 feed-shared-update-v2--minimal-padding full-height relative artdeco-card" data-urn="urn:li:activity:7140031369270779904" id="ember572" role="region">
#  <div>
#  <div role="status">
#  <!-- --> </div>
#  <h2 class="visually-hidden">
#                Publicação no feed
#            </h2>
#  <div class="update-components-actor display-flex update-components-actor--with-control-menu">
#  <!-- -->
#  <div class="update-components-actor__container pr4 display-flex flex-grow-1">
#  <a aria-label="SouJunior" class="app-aware-link update-components-actor__image relative" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="js-update-components-actor__avatar">
#  <div class="ivm-image-view-model update-components-actor__avatar">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered EntityPhoto-square-3 update-components-actor__avatar-image evi-image lazy-image ember-view" height="48" id="ember573" loading="lazy" src="https://media.licdn.com/dms/image/C4D0BAQFsFs3ksU63Sw/company-logo_100_100/0/1680116470998/soujunior_logo?e=1710979200&amp;v=beta&amp;t=8gEZpW8bj868ut4Vd-aBi9staxgoV4jutIHnfbl-1ZU" width="48"/>
#  </div>
#  </div>
#  </span>
#  </a>
#  <div class="update-components-actor__meta relative">
#  <a aria-label="Ver: SouJunior 61.476 seguidores" class="app-aware-link update-components-actor__meta-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="update-components-actor__title">
#  <span class="update-components-actor__name hoverable-link-text t-14 t-bold t-black">
#  <span dir="ltr"><span aria-hidden="true"><span><!-- -->SouJunior<!-- --></span></span><span class="visually-hidden"><!-- -->SouJunior<!-- --></span></span>
#  </span>
#  <!-- --> </span>
#  <span class="update-components-actor__description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->61.476 seguidores<!-- --></span><span class="visually-hidden"><!-- -->61.476 seguidores<!-- --></span>
#  </span>
#  </a>
#  <!-- --> <a aria-label="1 sem •   " class="app-aware-link update-components-actor__sub-description-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="update-components-actor__sub-description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->1 sem •<span class="white-space-pre"> </span><span> <li-icon aria-hidden="true" class="v-align-bottom" size="small" type="globe-americas"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 1a7 7 0 107 7 7 7 0 00-7-7zM3 8a5 5 0 011-3l.55.55A1.5 1.5 0 015 6.62v1.07a.75.75 0 00.22.53l.56.56a.75.75 0 00.53.22H7v.69a.75.75 0 00.22.53l.56.56a.75.75 0 01.22.53V13a5 5 0 01-5-5zm6.24 4.83l2-2.46a.75.75 0 00.09-.8l-.58-1.16A.76.76 0 0010 8H7v-.19a.51.51 0 01.28-.45l.38-.19a.74.74 0 01.68 0L9 7.5l.38-.7a1 1 0 00.12-.48v-.85a.78.78 0 01.21-.53l1.07-1.09a5 5 0 01-1.54 9z"></path>
#  </svg></li-icon>
#  </span><span class="white-space-pre"> </span><!-- --><!-- --></span><span class="visually-hidden"><!-- -->1 sem •<span class="white-space-pre"> </span></span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <div class="feed-shared-control-menu display-flex feed-shared-update-v2__control-menu absolute text-align-right">
#  <!-- -->
#  <div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view" id="ember575">
#  <button aria-expanded="false" class="feed-shared-control-menu__trigger artdeco-button artdeco-button--tertiary artdeco-button--muted artdeco-button--1 artdeco-button--circle artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" id="ember576" tabindex="0" type="button">
#  <svg aria-hidden="false" aria-label="Abrir menu de controle" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="overflow-web-ios-medium" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#overflow-web-ios-medium" width="24"></use>
#  </svg>
#  <!-- --></button>
#  <div aria-hidden="true" aria-label="Opções do menu de controle" class="feed-shared-control-menu__content artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--has-arrow artdeco-dropdown__content--arrow-right artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" id="ember577" tabindex="-1"><!-- --></div>
#  </div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- --><!-- --> </div>
#  <!-- -->
#  <!-- -->
#  <!-- --><!-- --> <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
#  <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding" tabindex="-1">
#  <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
#  <!-- -->
#  <span class="break-words">
#  <!-- --> <span dir="ltr"><!-- -->🌟 Anúncio de Evento Especial: Desvendando o Mundo do Low Code / No Code 🚀<!-- --><span><br/></span><span><br/></span><!-- -->Olá, Comunidade Soujunior!<!-- --><span><br/></span><span><br/></span><!-- -->É com grande entusiasmo que convido todos vocês para o nosso próximo evento, dedicado a explorar as maravilhas do universo Low Code / No Code. Este evento é uma oportunidade única para profissionais de todas as áreas.<!-- --><span><br/></span><span><br/></span><!-- -->Este evento é perfeito para quem busca estar à frente das tendências tecnológicas e quer entender como as soluções Low Code / No Code podem transformar negócios e carreiras.<!-- --><span><br/></span><span><br/></span><!-- -->Não perca esta oportunidade de se envolver, aprender e crescer com a comunidade de Low Code / No Code.<!-- --><span><br/></span><span><br/></span><!-- -->Esperamos ver você lá!<!-- --><span><br/></span><span><br/></span><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=lowcodenocode&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7140031369270779904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>LowCodeNoCode</span></a></span><span class="white-space-pre"> </span><!-- --><!-- --><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=tecnologia&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7140031369270779904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>Tecnologia</span></a></span><span class="white-space-pre"> </span><!-- --><!-- --><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=inova%C3%A7%C3%A3o&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7140031369270779904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>Inovação</span></a></span><span class="white-space-pre"> </span><!-- --><!-- --><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=evento&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7140031369270779904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>Evento</span></a></span><span class="white-space-pre"> </span><!-- --><!-- --><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=desenvolvimentodesoftware&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7140031369270779904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>DesenvolvimentoDeSoftware</span></a></span><span><br/></span><span><br/></span><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAAAdF6kIB40Yj228oznuTMkBmAAoYLhs4zYs" target="_self"><span><a class="ember-view" href="/in/brcassiano/" id="ember578"><!-- -->Bruno Cassiano<!-- --></a></span></a><span class="white-space-pre"> </span>- Palestrante.<!-- --><span><br/></span><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAAAWq8eEBWnGym0SA7ckH4cSt61nTi_mx0vY" target="_self"><span><a class="ember-view" href="/in/wouerner/" id="ember579"><!-- -->Wouerner ✝️ Brandão<!-- --></a></span></a><span class="white-space-pre"> </span>- Apresentador.<!-- --><span><br/></span><span><br/></span><!-- -->Vem<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior-labs/" target="_self"><span><span><!-- -->SouJunior Labs<!-- --></span></span></a><!-- -->!<!-- --></span>
#  </span>
#  </div>
#  <button aria-label="ver mais, revela visualmente conteúdos que já foram detectados por leitores de tela" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text" role="button" type="button">
#  <span class="feed-shared-inline-show-more-text__see-more-text">…ver mais</span>
#  </button>
#  <!-- --></div>
#  <!-- -->
#  <!-- --></div>
#  <!-- --> <div class="ember-view update-components-mini-update-v2 feed-shared-update-v2__update-content-wrapper artdeco-card" id="ember581">
#  <!-- -->
#  <div class="update-components-actor display-flex pt3">
#  <!-- -->
#  <div class="update-components-actor__container pr4 display-flex flex-grow-1">
#  <a aria-label="SouJunior" class="app-aware-link update-components-actor__image relative" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="js-update-components-actor__avatar">
#  <div class="ivm-image-view-model update-components-actor__avatar">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered EntityPhoto-square-2 update-components-actor__avatar-image evi-image lazy-image ember-view" height="40" id="ember582" loading="lazy" src="https://media.licdn.com/dms/image/C4D0BAQFsFs3ksU63Sw/company-logo_100_100/0/1680116470998/soujunior_logo?e=1710979200&amp;v=beta&amp;t=8gEZpW8bj868ut4Vd-aBi9staxgoV4jutIHnfbl-1ZU" width="40"/>
#  </div>
#  </div>
#  </span>
#  </a>
#  <div class="update-components-actor__meta relative">
#  <a aria-label="Ver: SouJunior 61.476 seguidores" class="app-aware-link update-components-actor__meta-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="update-components-actor__title">
#  <span class="update-components-actor__name hoverable-link-text t-14 t-bold t-black">
#  <span dir="ltr"><span aria-hidden="true"><span><!-- -->SouJunior<!-- --></span></span><span class="visually-hidden"><!-- -->SouJunior<!-- --></span></span>
#  </span>
#  <!-- --> </span>
#  <span class="update-components-actor__description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->61.476 seguidores<!-- --></span><span class="visually-hidden"><!-- -->61.476 seguidores<!-- --></span>
#  </span>
#  </a>
#  <!-- --> <a aria-label="2 sem •   " class="app-aware-link update-components-actor__sub-description-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="update-components-actor__sub-description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->2 sem •<span class="white-space-pre"> </span><span> <li-icon aria-hidden="true" class="v-align-bottom" size="small" type="globe-americas"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 1a7 7 0 107 7 7 7 0 00-7-7zM3 8a5 5 0 011-3l.55.55A1.5 1.5 0 015 6.62v1.07a.75.75 0 00.22.53l.56.56a.75.75 0 00.53.22H7v.69a.75.75 0 00.22.53l.56.56a.75.75 0 01.22.53V13a5 5 0 01-5-5zm6.24 4.83l2-2.46a.75.75 0 00.09-.8l-.58-1.16A.76.76 0 0010 8H7v-.19a.51.51 0 01.28-.45l.38-.19a.74.74 0 01.68 0L9 7.5l.38-.7a1 1 0 00.12-.48v-.85a.78.78 0 01.21-.53l1.07-1.09a5 5 0 01-1.54 9z"></path>
#  </svg></li-icon>
#  </span><span class="white-space-pre"> </span><!-- --><!-- --></span><span class="visually-hidden"><!-- -->2 sem •<span class="white-space-pre"> </span></span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <div class="mr2" style="" tabindex="-1">
#  <a class="tap-target update-components-mini-update-v2__link-to-details-page text-body-medium ember-view" href="/feed/update/urn:li:activity:7135312582470475776/" id="ember583" tabindex="-1">
#  <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding" tabindex="-1">
#  <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
#  <!-- -->
#  <span class="break-words">
#  <!-- --> <span dir="ltr"><!-- -->No Code / Low Code<!-- --><span><br/></span><span><br/></span></span>
#  </span>
#  </div>
#  <!-- --><!-- --></div>
#  <!-- -->
#  </a>
#  <!-- --></div>
#  <div class="update-components-linkedin-video update-components-mini-update-v2__reshared-content update-components-mini-update-v2__reshared-content--with-divider">
#  <div class="update-components-linkedin-video__container">
#  <!-- --> <div class="relative">
#  <a aria-label="No Code / Low Code" class="ember-view update-components-linkedin-video__live-external-link update-components-linkedin-video__live-external-link--was-live pt3" href="/video/event/urn:li:ugcPost:7135312581354749952/?isInternal=true" id="ember584">
#  <!-- --> <span class="update-components-linkedin-video__live-external-link-text t-sans t-14 t-white t-bold full-width text-align-center">
#  <div class="update-components-linkedin-video__live-external-link-see-more mb1 pv1 ph2">
#                    Ver mais
#                  </div>
#  </span>
#  </a>
#  <div class="video-live-feed full-height full-width">
#  <div class="video-live">
#  <div class="full-width live-video-loader video-s-loader video-live-loader video-s-loader--video-active video-s-loader--video-loading">
#  <div class="media-player video-s-loader__video-container" data-player-id="ember586">
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- --> <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div aria-label="Player de vídeo" class="ember-view video-js media-player__player vjs-fluid media-player--use-mercado vjs-controls-enabled vjs-workinghover vjs-v7 vjs-layout-small vjs-user-inactive vjs-has-started vjs-paused" data-vjs-player="" id="ember588" lang="pt" role="region" tabindex="-1" translate="no"><video autoplay="" class="vjs-tech" id="ember588_html5_api" muted="muted" poster="https://media.licdn.com/dms/image/D4E24AQFgSTQwd_3RQQ/feedshare-live-thumbnail_high/0/1702508440378?e=1703559600&amp;v=beta&amp;t=GoppXEtPhaKBq55GvjomsXO_43DMe5rwzDGVlOndq4Q" preload="metadata" src="blob:https://www.linkedin.com/d69d6509-e3fd-4fae-9aba-79a6ffb90e79"></video>
#  <div class="vjs-player-banner vjs-hide-on-inactivity" id="ember587">
#  <div>
#  <!-- -->
#  <!-- --> </div>
#  </div><div aria-disabled="false" class="vjs-poster" style='background-image: url("https://media.licdn.com/dms/image/D4E24AQFgSTQwd_3RQQ/feedshare-live-thumbnail_high/0/1702508440378?e=1703559600&amp;v=beta&amp;t=GoppXEtPhaKBq55GvjomsXO_43DMe5rwzDGVlOndq4Q");' tabindex="-1"></div><button aria-disabled="false" class="vjs-big-play-button" type="button"><span aria-hidden="true" class="vjs-icon-placeholder"></span><span aria-live="off" class="vjs-control-text">Reproduzir</span></button><div class="vjs-loading-spinner" dir="ltr"><span class="vjs-control-text">A mídia está carregando</span></div><div class="vjs-control-bar vjs-control-bar--tier" dir="ltr"><div class="vjs-progress-control vjs-control"><div aria-label="Progresso da reprodução" aria-valuemax="100" aria-valuemin="0" aria-valuenow="0.02" aria-valuetext="0:00:00 de 1:13:28" class="vjs-progress-holder vjs-slider vjs-slider-horizontal" role="slider" tabindex="0"><div class="vjs-load-progress" style="width: 0.73%;"><span class="vjs-control-text"><span>Carregado</span>: <span class="vjs-control-text-loaded-percentage">0.73%</span></span><div data-end="32" data-start="0.000166" style="left: 0%; width: 100%;"></div></div><div class="vjs-mouse-display"><div aria-hidden="true" class="vjs-time-tooltip"></div></div><div aria-hidden="true" class="vjs-play-progress vjs-slider-bar" style="width: 0.02%;"><div aria-hidden="true" class="vjs-time-tooltip" style="right: 0px;">0:00:00</div></div></div></div><button aria-disabled="false" class="vjs-play-control vjs-control vjs-button vjs-paused" type="button"><span aria-hidden="true" class="vjs-icon-placeholder"></span><span aria-live="off" class="vjs-control-text">Reproduzir</span><div class="vjs-tooltip-container vjs-tooltip-left"><div aria-hidden="true" class="vjs-tooltip" role="tooltip">Reproduzir</div></div></button><button aria-disabled="false" class="vjs-control vjs-button vjs-back-to-start-button" type="button"><span aria-hidden="true" class="vjs-icon-placeholder"></span><span aria-live="off" class="vjs-control-text">Voltar ao iníciodo vídeo</span><div class="vjs-tooltip-container vjs-tooltip-left"><div aria-hidden="true" class="vjs-tooltip" role="tooltip">Voltar ao início</div></div></button><button aria-disabled="false" class="vjs-control vjs-button vjs-skip-back-button" type="button"><span aria-hidden="true" class="vjs-icon-placeholder"></span><span aria-live="off" class="vjs-control-text">Pular para trás 10 segundos</span><div class="vjs-tooltip-container vjs-tooltip-left"><div aria-hidden="true" class="vjs-tooltip" role="tooltip">Pular para trás</div></div></button><button aria-disabled="false" class="vjs-control vjs-button vjs-skip-ahead-button" type="button"><span aria-hidden="true" class="vjs-icon-placeholder"></span><span aria-live="off" class="vjs-control-text">Pular adiante 10 segundos</span><div class="vjs-tooltip-container vjs-tooltip-left"><div aria-hidden="true" class="vjs-tooltip" role="tooltip">Pular adiante</div></div></button><div class="vjs-live-control vjs-control vjs-hidden"><div aria-live="off" class="vjs-live-display"><span class="vjs-control-text">Tipo de transmissão </span>Ao vivo</div></div><div class="vjs-time-display vjs-control" translate="no"><div class="vjs-current-time vjs-time-control vjs-control"><span class="vjs-control-text" role="presentation">Tempo atual </span><span aria-live="off" class="vjs-current-time-display" role="presentation">0:00</span></div><div aria-hidden="true" class="vjs-time-control vjs-time-divider"><div><span>/</span></div></div><div class="vjs-duration vjs-time-control vjs-control"><span class="vjs-control-text" role="presentation">Duração </span><span aria-live="off" class="vjs-duration-display" role="presentation">1:13:28</span></div></div><div class="vjs-custom-control-spacer vjs-spacer"> </div><div class="vjs-playback-rate vjs-menu-button vjs-menu-button-popup vjs-control vjs-button"><div aria-hidden="true" class="vjs-playback-rate-value" id="vjs-playback-rate-value-label- ...
#  <!-- --></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <a class="ember-view update-components-scheduled-live-content__event-link" href="/video/event/urn:li:ugcPost:7135312581354749952/?isInternal=true" id="ember589">
#  <div class="p3">
#  <p class="t-12 t-bold mb1">
#  <span class="tvm__text tvm__text--negative"><!-- -->O evento terminou<!-- --></span>
#  </p>
#  <h2 class="t-14 t-bold mb1">
#  <span dir="ltr"><!-- -->No Code / Low Code<!-- --></span>
#  </h2>
#  <p class="t-12 t-normal t-black--light mb1">
#  <li-icon aria-hidden="true" class="v-align-text-bottom" size="small" type="video-camera"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M3 3h8v10H3a2 2 0 01-2-2V5a2 2 0 012-2zm10.5 1l-1.5.75v6.5l1.5.75H15V4z"></path>
#  </svg></li-icon>
#  <span class="white-space-pre"> </span>LinkedIn Live<!-- -->
#  </p>
#  <!-- --> <div class="display-flex align-items-center">
#  <div class="ivm-image-view-model mr1">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered EntityPhoto-circle-1 evi-image lazy-image ember-view" height="32" id="ember590" loading="lazy" src="https://media.licdn.com/dms/image/D4D03AQFJLpkohgZUaA/profile-displayphoto-shrink_100_100/0/1702629774125?e=1708560000&amp;v=beta&amp;t=td6xklreBrYOhsNVnl5u0hiiTJjxYx1YS9tERyjaKtk" width="32"/>
#  </div>
#  </div>
#  <div class="text-body-xsmall t-black--light">
#  <!-- -->Wouerner ✝️ Brandão e mais 60 participantes<!-- -->
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  <!-- --><!-- --><!-- --><!-- --></div>
#  <!-- -->
#  <!-- --><!-- --> </div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="update-v2-social-activity" id="ember591">
#  <div class="social-details-social-counts">
#  <div class="display-flex flex-grow-1">
#  <div class="relative full-width">
#  <ul class="display-flex">
#  <li class="social-details-social-counts__item social-details-social-counts__reactions social-details-social-counts__reactions--left-aligned">
#  <button aria-label="14 reações" class="t-black--light display-flex align-items-center social-details-social-counts__count-value t-12 hoverable-link-text" type="button">
#  <img alt="like" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--0 reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="LIKE" src="https://static.licdn.com/aero-v1/sc/h/8ekq8gho1ruaf8i7f86vd1ftt"/>
#  <img alt="support" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--1 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-APPRECIATION data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="APPRECIATION" src="https://static.licdn.com/aero-v1/sc/h/3wqhxqtk2l554o70ur3kessf1"/>
#  <span class="social-details-social-counts__social-proof-container">
#  <span aria-hidden="true" class="social-details-social-counts__social-proof-fallback-number">15</span>
#  <span class="social-details-social-counts__social-proof-text">
#                          Wouerner ✝️ Brandão e mais 14 pessoas
#                    </span>
#  </span>
#  </button>
#  </li>
#  <li class="social-details-social-counts__item social-details-social-counts__comments social-details-social-counts__item--right-aligned">
#  <button aria-label="1 comentário" class="t-black--light social-details-social-counts__count-value t-12 hoverable-link-text" type="button">
#  <span aria-hidden="true">
#                      1 comentário
#                                    </span>
#  </button>
#  </li>
#  <li class="social-details-social-counts__item social-details-social-counts__item--right-aligned">
#  <button aria-label="1 compartilhamento" class="ember-view t-black--light t-12 hoverable-link-text" id="ember592">
#  <span aria-hidden="true">
#                      1 compartilhamento
#                  </span>
#  </button>
#  </li>
#  <!-- --> </ul>
#  <!-- --> </div>
#  </div>
#  <!-- --></div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="feed-shared-social-action-bar feed-shared-social-action-bar--full-width feed-shared-social-action-bar--has-social-counts">
#  <!-- -->
#  <span class="reactions-react-button feed-shared-social-action-bar__action-button">
#  <!-- -->
#  <button aria-label="Reagir com gostei" aria-pressed="false" class="artdeco-button artdeco-button--muted artdeco-button--4 artdeco-button--tertiary ember-view social-actions-button react-button__trigger" data-finite-scroll-hotkey="l" id="ember593"><!-- -->
#  <span class="artdeco-button__text">
#  <div class="flex-wrap justify-center artdeco-button__text align-items-center">
#  <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="thumbs-up-outline-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#thumbs-up-outline-medium" width="24"></use>
#  </svg>
#  <span aria-hidden="true" class="artdeco-button__text react-button__text social-action-button__text">
#                Gostei
#              </span>
#  </div>
#  </span></button>
#  <button aria-expanded="false" aria-label="Abrir menu de reações" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view reactions-menu__trigger" id="ember594"><!-- -->
#  <span class="artdeco-button__text">
#  <svg aria-hidden="true" data-supported-dps="16x16" data-test-icon="caret-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#caret-small" width="16"></use>
#  </svg>
#  </span></button>
#  </span>
#  <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view feed-shared-social-action-bar__action-button" id="ember595" tabindex="-1">
#  <div>
#  <button aria-label="Comentar" class="artdeco-button artdeco-button--muted artdeco-button--4 artdeco-button--tertiary ember-view social-actions-button comment-button flex-wrap" data-finite-scroll-hotkey="c" id="ember596" role="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="comment-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#comment-medium" width="24"></use>
#  </svg>
#  <span class="artdeco-button__text">
#      Comentar
#  </span></button>
#  </div>
#  <div class="ember-view" id="artdeco-gen-60"><div class="ember-view" id="ember598"></div></div>
#  </span>
#  <div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view feed-shared-social-action-bar__action-button" id="ember599">
#  <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view flex-1" id="ember601" tabindex="-1">
#  <button aria-expanded="false" aria-label="" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view artdeco-button social-actions-button social-reshare-button flex-wrap artdeco-button--muted artdeco-button--4 artdeco-button--tertiary" data-finite-scroll-hotkey="r" id="ember602" tabindex="0" type="button">
#  <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="repost-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#repost-medium" width="24"></use>
#  </svg>
#  <span class="artdeco-button__text social-action-button__text">Compartilhar</span>
#  <!-- --></button>
#  <div aria-hidden="true" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view social-reshare-button__share-dropdown-content" id="ember603" tabindex="-1"><!-- --></div>
#  <div class="ember-view" id="artdeco-gen-61"><div class="ember-view" id="ember605"></div></div>
#  </span>
#  <div>
#  <!-- -->
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <div class="feed-shared-social-action-bar__action-button">
#  <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view" id="ember606" tabindex="-1">
#  <button aria-label="Enviar em mensagem privada" class="social-actions-button send-privately-button artdeco-button artdeco-button--4 artdeco-button--tertiary flex-wrap artdeco-button--muted send-privately-button" data-finite-scroll-hotkey="s" type="button">
#  <svg aria-hidden="true" class="rtl-flip" data-supported-dps="24x24" data-test-icon="send-privately-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#send-privately-medium" width="24"></use>
#  </svg>
#  <span class="artdeco-button__text social-action-button__text">Enviar</span>
#  </button>
#  <div class="ember-view" id="artdeco-gen-62"><div class="ember-view" id="ember608"></div></div>
#  </span>
#  </div>
#  </div>
#  <!-- --><!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <span aria-label="" aria-live="polite" class="visually-hidden" role="alert"></span>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="feed-shared-update-v2__comments-container display-flex flex-column">
#  <!-- --><!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="ember-view" id="ember609"><!-- --></div>
#  <!-- -->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- -->
#  </div>,
#  <div>
#  <div class="ember-view occludable-update" id="ember439">
#  <div class="full-height">
#  <div class="full-height">
#  <div class="feed-shared-update-v2 feed-shared-update-v2--minimal-padding full-height relative artdeco-card" data-urn="urn:li:activity:7142645870126137344" id="ember481" role="region">
#  <div>
#  <div role="status">
#  <!-- --> </div>
#  <h2 class="visually-hidden">
#                Publicação no feed
#            </h2>
#  <div class="update-components-actor display-flex update-components-actor--with-control-menu">
#  <!-- -->
#  <div class="update-components-actor__container pr4 display-flex flex-grow-1">
#  <a aria-label="SouJunior" class="app-aware-link update-components-actor__image relative" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="js-update-components-actor__avatar">
#  <div class="ivm-image-view-model update-components-actor__avatar">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered EntityPhoto-square-3 update-components-actor__avatar-image evi-image lazy-image ember-view" height="48" id="ember482" loading="lazy" src="https://media.licdn.com/dms/image/C4D0BAQFsFs3ksU63Sw/company-logo_100_100/0/1680116470998/soujunior_logo?e=1710979200&amp;v=beta&amp;t=8gEZpW8bj868ut4Vd-aBi9staxgoV4jutIHnfbl-1ZU" width="48"/>
#  </div>
#  </div>
#  </span>
#  </a>
#  <div class="update-components-actor__meta relative">
#  <a aria-label="Ver: SouJunior 61.476 seguidores" class="app-aware-link update-components-actor__meta-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="update-components-actor__title">
#  <span class="update-components-actor__name hoverable-link-text t-14 t-bold t-black">
#  <span dir="ltr"><span aria-hidden="true"><span><!-- -->SouJunior<!-- --></span></span><span class="visually-hidden"><!-- -->SouJunior<!-- --></span></span>
#  </span>
#  <!-- --> </span>
#  <span class="update-components-actor__description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->61.476 seguidores<!-- --></span><span class="visually-hidden"><!-- -->61.476 seguidores<!-- --></span>
#  </span>
#  </a>
#  <!-- --> <a aria-label="3 h •   " class="app-aware-link update-components-actor__sub-description-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A82326952" target="_self">
#  <span class="update-components-actor__sub-description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->3 h •<span class="white-space-pre"> </span><span> <li-icon aria-hidden="true" class="v-align-bottom" size="small" type="globe-americas"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 1a7 7 0 107 7 7 7 0 00-7-7zM3 8a5 5 0 011-3l.55.55A1.5 1.5 0 015 6.62v1.07a.75.75 0 00.22.53l.56.56a.75.75 0 00.53.22H7v.69a.75.75 0 00.22.53l.56.56a.75.75 0 01.22.53V13a5 5 0 01-5-5zm6.24 4.83l2-2.46a.75.75 0 00.09-.8l-.58-1.16A.76.76 0 0010 8H7v-.19a.51.51 0 01.28-.45l.38-.19a.74.74 0 01.68 0L9 7.5l.38-.7a1 1 0 00.12-.48v-.85a.78.78 0 01.21-.53l1.07-1.09a5 5 0 01-1.54 9z"></path>
#  </svg></li-icon>
#  </span><span class="white-space-pre"> </span><!-- --><!-- --></span><span class="visually-hidden"><!-- -->3 h •<span class="white-space-pre"> </span></span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <div class="feed-shared-control-menu display-flex feed-shared-update-v2__control-menu absolute text-align-right">
#  <!-- -->
#  <div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view" id="ember484">
#  <button aria-expanded="false" class="feed-shared-control-menu__trigger artdeco-button artdeco-button--tertiary artdeco-button--muted artdeco-button--1 artdeco-button--circle artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" id="ember485" tabindex="0" type="button">
#  <svg aria-hidden="false" aria-label="Abrir menu de controle" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="overflow-web-ios-medium" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#overflow-web-ios-medium" width="24"></use>
#  </svg>
#  <!-- --></button>
#  <div aria-hidden="true" aria-label="Opções do menu de controle" class="feed-shared-control-menu__content artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--has-arrow artdeco-dropdown__content--arrow-right artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" id="ember486" tabindex="-1"><!-- --></div>
#  </div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- --><!-- --> </div>
#  <!-- -->
#  <!-- -->
#  <!-- --><!-- --> <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
#  <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding" tabindex="-1">
#  <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
#  <!-- -->
#  <span class="break-words">
#  <!-- --> <span dir="ltr"><!-- -->💙<!-- --></span>
#  </span>
#  </div>
#  <!-- --><!-- --></div>
#  <!-- -->
#  <!-- --></div>
#  <!-- --> <div class="ember-view update-components-mini-update-v2 feed-shared-update-v2__update-content-wrapper artdeco-card" id="ember488">
#  <!-- -->
#  <div class="update-components-actor display-flex pt3">
#  <!-- -->
#  <div class="update-components-actor__container pr4 display-flex flex-grow-1">
#  <a aria-label="Herian Cavalcante" class="app-aware-link update-components-actor__image relative" data-test-app-aware-link="" href="https://www.linkedin.com/in/heriancavalcante?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAC6v9G8BRSm6Jlu0I4QnM2yklit0N5D4FqQ" target="_self">
#  <span class="js-update-components-actor__avatar">
#  <div class="ivm-image-view-model update-components-actor__avatar">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered EntityPhoto-circle-2 update-components-actor__avatar-image evi-image lazy-image ember-view" height="40" id="ember489" loading="lazy" src="https://media.licdn.com/dms/image/C4D03AQHNYT33A8ydWQ/profile-displayphoto-shrink_100_100/0/1584030015399?e=1708560000&amp;v=beta&amp;t=6BqrKd0B2LPFusaZs4Wuv_s3Lh-jGe0XurVfoRGgk2E" width="40"/>
#  </div>
#  </div>
#  </span>
#  </a>
#  <div class="update-components-actor__meta relative">
#  <a aria-label="Ver: Herian Cavalcante • 3º e + Graduando em Ciências Matemáticas e da Terra - UFRJ" class="app-aware-link update-components-actor__meta-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/heriancavalcante?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAC6v9G8BRSm6Jlu0I4QnM2yklit0N5D4FqQ" target="_self">
#  <span class="update-components-actor__title">
#  <span class="update-components-actor__name hoverable-link-text t-14 t-bold t-black">
#  <span dir="ltr"><span aria-hidden="true"><!-- -->Herian Cavalcante<!-- --></span><span class="visually-hidden"><!-- -->Herian Cavalcante<!-- --></span></span>
#  </span>
#  <span class="update-components-actor__supplementary-actor-info t-black--light t-14 t-normal">
#  <span aria-hidden="true"><span class="white-space-pre"> </span>• 3º e +<!-- --></span><span class="visually-hidden"><span class="white-space-pre"> </span>• 3º e +<!-- --></span>
#  </span>
#  </span>
#  <span class="update-components-actor__description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->Graduando em Ciências Matemáticas e da Terra - UFRJ<!-- --></span><span class="visually-hidden"><!-- -->Graduando em Ciências Matemáticas e da Terra - UFRJ<!-- --></span>
#  </span>
#  </a>
#  <!-- --> <a aria-label="10 h • Editado •   " class="app-aware-link update-components-actor__sub-description-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/heriancavalcante?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAC6v9G8BRSm6Jlu0I4QnM2yklit0N5D4FqQ" target="_self">
#  <span class="update-components-actor__sub-description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->10 h • Editado •<span class="white-space-pre"> </span><span> <li-icon aria-hidden="true" class="v-align-bottom" size="small" type="globe-americas"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 1a7 7 0 107 7 7 7 0 00-7-7zM3 8a5 5 0 011-3l.55.55A1.5 1.5 0 015 6.62v1.07a.75.75 0 00.22.53l.56.56a.75.75 0 00.53.22H7v.69a.75.75 0 00.22.53l.56.56a.75.75 0 01.22.53V13a5 5 0 01-5-5zm6.24 4.83l2-2.46a.75.75 0 00.09-.8l-.58-1.16A.76.76 0 0010 8H7v-.19a.51.51 0 01.28-.45l.38-.19a.74.74 0 01.68 0L9 7.5l.38-.7a1 1 0 00.12-.48v-.85a.78.78 0 01.21-.53l1.07-1.09a5 5 0 01-1.54 9z"></path>
#  </svg></li-icon>
#  </span><span class="white-space-pre"> </span><!-- --><!-- --></span><span class="visually-hidden"><!-- -->10 h • Editado •<span class="white-space-pre"> </span></span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <div class="mr2" style="" tabindex="-1">
#  <a class="tap-target update-components-mini-update-v2__link-to-details-page text-body-medium ember-view" href="/feed/update/urn:li:activity:7142543649430536193/" id="ember490" tabindex="-1">
#  <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding" tabindex="-1">
#  <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
#  <!-- -->
#  <span class="break-words">
#  <!-- --> <span dir="ltr"><!-- -->Empolgado em Compartilhar meu Primeiro Projeto em Python! 🐍<!-- --><span><br/></span><span><br/></span><!-- -->Olá, rede LinkedIn!<!-- --><span><br/></span><!-- -->Estou feliz em compartilhar meu primeiro projeto em Python, uma conquista que marca um passo significativo em minha jornada na área de programação! Este trabalho foi desenvolvido como parte da disciplina de Computação 2 na UFRJ, e representa não apenas uma entrega acadêmica, mas uma verdadeira imersão no mundo da análise de dados.<!-- --><span><br/></span><span><br/></span><!-- -->Sobre o Projeto: O trabalho consistia em criar um sistema que utilizasse tópicos de programação orientada a objetos. Além disso, o trabalho deveria abordar um tema relacionado ao curso do discente (Ciências Matemáticas e da Terra).<!-- --><span><br/></span><!-- -->Dessa forma, criei um sistema de informação sobre os dados de poluição do ar no Rio. O app se propõe a disponibilizar os dados de um período selecionado pelo usuário, tendo em vista que o boletim da prefeitura dá apenas os índices diários. Ao final, o usuário pode ter uma breve visualização dos dados consultados, podendo também carregar as informações em planilha ou csv.<span class="white-space-pre"> </span><span><br/></span><!-- -->Utilizei algumas ferramentas de análise de dados com Python como: Requests, BeautifulSoup e Pandas.<!-- --><span><br/></span><span><br/></span><!-- -->Ainda há muito o que melhorar no sistema, mas estou feliz pelo resultado que obtive. Pretendo adicionar novas features ao longo do tempo.<span class="white-space-pre"> </span><span><br/></span><span><br/></span><!-- -->Gostaria de agradecer aos meus colegas de turma e ao meu professor Luiz Paulo Carvalho que me ajudaram nesse projeto. Quero agradecer também a<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAAAXhcEkBKS3xy5-r9Hgp9YKnZ8ZSIHo6Hs0" target="_self"><span><a class="ember-view" href="/in/kizzyterra/" id="ember491"><!-- -->Kizzy Terra<!-- --></a></span></a><span class="white-space-pre"> </span>e o<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAAAYAkrABdnEGEXZWIc2cKG6GeppIKOEkokI" target="_self"><span><a class="ember-view" href="/in/hallpaz/" id="ember492"><!-- -->Hallison Paz<!-- --></a></span></a><span class="white-space-pre"> </span>por disponibilizar diversos conteúdos gratuitos sobre Programação e Ciência de Dados no YouTube, além de serem minhas inspirações na área de dados.<!-- --><span><br/></span><span><br/></span><!-- -->Repositório no GitHub:<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/erkZbiuH" target="_self"><!-- -->https://lnkd.in/erkZbiuH<!-- --></a><span><br/></span><span><br/></span><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=python&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7142645870126137344"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>Python</span></a></span><span class="white-space-pre"> </span><!-- --><!-- --><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=ci%C3%AAnciadedados&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7142645870126137344"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>CiênciaDeDados</span></a></span><span class="white-space-pre"> </span><!-- --><!-- --><span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=desenvolvimentodesoftware&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7142645870126137344"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>DesenvolvimentoDeSoftware</span></a></span><span class="white-space-pre"> </span><!-- --><!--  ...
#  </span>
#  </div>
#  <button aria-label="ver mais, revela visualmente conteúdos que já foram detectados por leitores de tela" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text" role="button" type="button">
#  <span class="feed-shared-inline-show-more-text__see-more-text">…ver mais</span>
#  </button>
#  <!-- --></div>
#  <!-- -->
#  </a>
#  <!-- --></div>
#  <div class="update-components-linkedin-video update-components-mini-update-v2__reshared-content update-components-mini-update-v2__reshared-content--with-divider">
#  <div class="update-components-linkedin-video__container">
#  <!-- --> <div class="video-s-loader video-s-loader--video-active video-s-loader--video-loading">
#  <div class="media-player video-s-loader__video-container video-s-loader__video-container--immersive-player-controls" data-player-id="ember494">
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div aria-label="Player de vídeo" class="ember-view video-js media-player__player vjs-fluid media-player--use-mercado vjs-controls-enabled vjs-workinghover vjs-v7 vjs-layout-small vjs-has-started vjs-paused vjs-user-inactive" data-vjs-player="" id="ember495" lang="pt" role="region" tabindex="-1" translate="no"><div class="vjs-poster-background" style='background-image: url("https://media.licdn.com/dms/image/D4E05AQE1mvvt8iRALw/videocover-low/0/1702915062472?e=1703559600&amp;v=beta&amp;t=bTgxbWwqzeoBQ1Y8CqO-TouxgTsS1N4Tu-L-tQB7Vxw");'></div><video autoplay="autoplay" class="vjs-tech" id="ember495_html5_api" muted="muted" poster="https://media.licdn.com/dms/image/D4E05AQE1mvvt8iRALw/videocover-low/0/1702915062472?e=1703559600&amp;v=beta&amp;t=bTgxbWwqzeoBQ1Y8CqO-TouxgTsS1N4Tu-L-tQB7Vxw" preload="metadata" role="application" src="blob:https://www.linkedin.com/8c328ca6-2e5e-453f-a9b0-42c4b1a1ef43" tabindex="-1"></video>
# ...
#  <button aria-expanded="false" class="feed-shared-control-menu__trigger artdeco-button artdeco-button--tertiary artdeco-button--muted artdeco-button--1 artdeco-button--circle artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" id="ember753" tabindex="0" type="button">
#  <svg aria-hidden="false" aria-label="Abrir menu de controle" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="overflow-web-ios-medium" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#overflow-web-ios-medium" width="24"></use>
#  </svg>
#  <!-- --></button>
#  <div aria-hidden="true" aria-label="Opções do menu de controle" class="feed-shared-control-menu__content artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--has-arrow artdeco-dropdown__content--arrow-right artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" id="ember754" tabindex="-1"><!-- --></div>
#  </div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- --><!-- --> </div>
#  <!-- --><!-- --> <div class="update-components-actor display-flex">
#  <!-- -->
#  <div class="update-components-actor__container pr4 display-flex flex-grow-1">
#  <a aria-label="Rodrigo Piano" class="app-aware-link update-components-actor__image relative" data-test-app-aware-link="" href="https://www.linkedin.com/in/rodrigopiano?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADUIUuwBTIefbMzMev8Te5nW_6ndjw8pWl0" target="_self">
#  <span class="js-update-components-actor__avatar">
#  <div class="ivm-image-view-model update-components-actor__avatar">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered EntityPhoto-circle-3 update-components-actor__avatar-image evi-image lazy-image ember-view" height="48" id="ember755" loading="lazy" src="https://media.licdn.com/dms/image/D4D03AQHYpAoN_tNWeA/profile-displayphoto-shrink_100_100/0/1688043756378?e=1708560000&amp;v=beta&amp;t=204CoCpv7tp3sC0RrTgdKzh_pQhWVbfhGI9_7k3TU0k" width="48"/>
#  </div>
#  </div>
#  </span>
#  </a>
#  <div class="update-components-actor__meta relative">
#  <a aria-label="Ver: Rodrigo Piano • 1º UX/UI Designer (Voluntário) na SouJunior" class="app-aware-link update-components-actor__meta-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/rodrigopiano?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADUIUuwBTIefbMzMev8Te5nW_6ndjw8pWl0" target="_self">
#  <span class="update-components-actor__title">
#  <span class="update-components-actor__name hoverable-link-text t-14 t-bold t-black">
#  <span dir="ltr"><span aria-hidden="true"><!-- -->Rodrigo Piano<!-- --></span><span class="visually-hidden"><!-- -->Rodrigo Piano<!-- --></span></span>
#  </span>
#  <span class="update-components-actor__supplementary-actor-info t-black--light t-14 t-normal">
#  <span aria-hidden="true"><span class="white-space-pre"> </span>• 1º<!-- --></span><span class="visually-hidden"><span class="white-space-pre"> </span>• 1º<!-- --></span>
#  </span>
#  </span>
#  <span class="update-components-actor__description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->UX/UI Designer (Voluntário) na SouJunior<!-- --></span><span class="visually-hidden"><!-- -->UX/UI Designer (Voluntário) na SouJunior<!-- --></span>
#  </span>
#  </a>
#  <!-- --> <a aria-label="4 d •   " class="app-aware-link update-components-actor__sub-description-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/rodrigopiano?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADUIUuwBTIefbMzMev8Te5nW_6ndjw8pWl0" target="_self">
#  <span class="update-components-actor__sub-description t-black--light t-12 t-normal">
#  <span aria-hidden="true"><!-- -->4 d •<span class="white-space-pre"> </span><span> <li-icon aria-hidden="true" class="v-align-bottom" size="small" type="globe-americas"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 1a7 7 0 107 7 7 7 0 00-7-7zM3 8a5 5 0 011-3l.55.55A1.5 1.5 0 015 6.62v1.07a.75.75 0 00.22.53l.56.56a.75.75 0 00.53.22H7v.69a.75.75 0 00.22.53l.56.56a.75.75 0 01.22.53V13a5 5 0 01-5-5zm6.24 4.83l2-2.46a.75.75 0 00.09-.8l-.58-1.16A.76.76 0 0010 8H7v-.19a.51.51 0 01.28-.45l.38-.19a.74.74 0 01.68 0L9 7.5l.38-.7a1 1 0 00.12-.48v-.85a.78.78 0 01.21-.53l1.07-1.09a5 5 0 01-1.54 9z"></path>
#  </svg></li-icon>
#  </span><span class="white-space-pre"> </span><!-- --><!-- --></span><span class="visually-hidden"><!-- -->4 d •<span class="white-space-pre"> </span></span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <!-- -->
#  <!-- -->
#  <!-- --><!-- --> <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
#  <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding" tabindex="-1">
#  <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
#  <!-- -->
#  <span class="break-words">
#  <!-- --> <span dir="ltr"><!-- -->Hoy fue la última alineación del equipo de UX de la<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/soujunior/" target="_self"><span><span><!-- -->SouJunior<!-- --></span></span></a><!-- -->.<!-- --><span><br/></span><span><br/></span><!-- -->Estoy muy contento de estar en este proyecto como diseñador de interfaz, está brindando una experiencia increíble.<!-- --><span><br/></span><span><br/></span><!-- -->Gracias a todos por todo el aprendizaje.<!-- --><span><br/></span><span><br/></span><!-- -->En 2024, estaremos juntos.<!-- --></span>
#  </span>
#  </div>
#  <button aria-label="ver mais, revela visualmente conteúdos que já foram detectados por leitores de tela" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text" role="button" type="button">
#  <span class="feed-shared-inline-show-more-text__see-more-text">…ver mais</span>
#  </button>
#  <!-- --></div>
#  <!-- -->
#  <div>
#  <div class="feed-shared-see-translation-button">
#  <!-- -->
#  <button class="artdeco-button artdeco-button--1 artdeco-button--tertiary ember-view" id="ember756"><!-- -->
#  <span class="artdeco-button__text">
#      Visualizar tradução
#  </span></button>
#  <!-- --> </div>
#  </div>
#  </div>
#  <div class="update-components-image update-components-image--single-image feed-shared-update-v2__content">
#  <div class="relative">
#  <div class="update-components-image__container" style="padding-top: 45.97%;">
#  <button class="update-components-image__image-link" type="button">
#  <span class="visually-hidden">
#                    Ative para ver a imagem maior.
#                  </span>
#  <div class="ivm-image-view-model">
#  <div class="ivm-view-attr__img-wrapper display-flex">
#  <!-- --> <img alt="Pré-visualização da imagem" class="ivm-view-attr__img--centered ivm-view-attr__img--aspect-fill update-components-image__image evi-image lazy-image ember-view" height="275" id="ember758" loading="lazy" src="https://media.licdn.com/dms/image/D4D22AQHaEeY1EzV9Sg/feedshare-shrink_800/0/1702591004777?e=1706140800&amp;v=beta&amp;t=VslB_lQXBCy-wXTSl7B_4cBCjFXuGfGJmOXnLCNcljg" width="600"/>
#  </div>
#  </div>
#  </button>
#  <!-- --> <!-- --> </div>
#  <span aria-hidden="true" class="visually-hidden" id="update-components-image-ember757">
#            Ative para ver a imagem maior.
#      </span>
#  <!-- -->
#  <!-- --> </div>
#  <!-- -->
#  <!-- --></div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="update-v2-social-activity" id="ember759">
#  <div class="social-details-social-counts">
#  <div class="display-flex flex-grow-1">
#  <div class="relative full-width">
#  <ul class="display-flex">
#  <li class="social-details-social-counts__item social-details-social-counts__reactions social-details-social-counts__reactions--left-aligned">
#  <button aria-label="14 reações" class="t-black--light display-flex align-items-center social-details-social-counts__count-value t-12 hoverable-link-text" type="button">
#  <img alt="like" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--0 reactions-icon__consumption--small data-test-reactions-icon-type-LIKE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="LIKE" src="https://static.licdn.com/aero-v1/sc/h/8ekq8gho1ruaf8i7f86vd1ftt"/>
#  <img alt="celebrate" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--1 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-PRAISE data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="PRAISE" src="https://static.licdn.com/aero-v1/sc/h/b1dl5jk88euc7e9ri50xy5qo8"/>
#  <img alt="love" class="reactions-icon social-detail-social-counts__count-icon social-detail-social-counts__count-icon--2 reactions-icon__consumption--small reactions-icon--stacked data-test-reactions-icon-type-EMPATHY data-test-reactions-icon-theme-light" data-test-reactions-icon-theme="light" data-test-reactions-icon-type="EMPATHY" src="https://static.licdn.com/aero-v1/sc/h/cpho5fghnpme8epox8rdcds22"/>
#  <span class="social-details-social-counts__social-proof-container">
#  <span aria-hidden="true" class="social-details-social-counts__social-proof-fallback-number">15</span>
#  <span class="social-details-social-counts__social-proof-text">
#                          Wouerner ✝️ Brandão e mais 14 pessoas
#                    </span>
#  </span>
#  </button>
#  </li>
#  <li class="social-details-social-counts__item social-details-social-counts__comments social-details-social-counts__item--right-aligned">
#  <button aria-label="1 comentário" class="t-black--light social-details-social-counts__count-value t-12 hoverable-link-text" type="button">
#  <span aria-hidden="true">
#                      1 comentário
#                                    </span>
#  </button>
#  </li>
#  <li class="social-details-social-counts__item social-details-social-counts__item--right-aligned">
#  <button aria-label="1 compartilhamento" class="ember-view t-black--light t-12 hoverable-link-text" id="ember760">
#  <span aria-hidden="true">
#                      1 compartilhamento
#                  </span>
#  </button>
#  </li>
#  <!-- --> </ul>
#  <!-- --> </div>
#  </div>
#  <!-- --></div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="feed-shared-social-action-bar feed-shared-social-action-bar--full-width feed-shared-social-action-bar--has-social-counts">
#  <!-- -->
#  <span class="reactions-react-button feed-shared-social-action-bar__action-button">
#  <!-- -->
#  <button aria-label="Reagir com gostei" aria-pressed="false" class="artdeco-button artdeco-button--muted artdeco-button--4 artdeco-button--tertiary ember-view social-actions-button react-button__trigger" data-finite-scroll-hotkey="l" id="ember761"><!-- -->
#  <span class="artdeco-button__text">
#  <div class="flex-wrap justify-center artdeco-button__text align-items-center">
#  <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="thumbs-up-outline-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#thumbs-up-outline-medium" width="24"></use>
#  </svg>
#  <span aria-hidden="true" class="artdeco-button__text react-button__text social-action-button__text">
#                Gostei
#              </span>
#  </div>
#  </span></button>
#  <button aria-expanded="false" aria-label="Abrir menu de reações" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view reactions-menu__trigger" id="ember762"><!-- -->
#  <span class="artdeco-button__text">
#  <svg aria-hidden="true" data-supported-dps="16x16" data-test-icon="caret-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#caret-small" width="16"></use>
#  </svg>
#  </span></button>
#  </span>
#  <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view feed-shared-social-action-bar__action-button" id="ember763" tabindex="-1">
#  <div>
#  <button aria-label="Comentar" class="artdeco-button artdeco-button--muted artdeco-button--4 artdeco-button--tertiary ember-view social-actions-button comment-button flex-wrap" data-finite-scroll-hotkey="c" id="ember764" role="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="comment-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#comment-medium" width="24"></use>
#  </svg>
#  <span class="artdeco-button__text">
#      Comentar
#  </span></button>
#  </div>
#  <div class="ember-view" id="artdeco-gen-72"><div class="ember-view" id="ember766"></div></div>
#  </span>
#  <div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view feed-shared-social-action-bar__action-button" id="ember767">
#  <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view flex-1" id="ember769" tabindex="-1">
#  <button aria-expanded="false" aria-label="" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view artdeco-button social-actions-button social-reshare-button flex-wrap artdeco-button--muted artdeco-button--4 artdeco-button--tertiary" data-finite-scroll-hotkey="r" id="ember770" tabindex="0" type="button">
#  <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="24x24" data-test-icon="repost-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#repost-medium" width="24"></use>
#  </svg>
#  <span class="artdeco-button__text social-action-button__text">Compartilhar</span>
#  <!-- --></button>
#  <div aria-hidden="true" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view social-reshare-button__share-dropdown-content" id="ember771" tabindex="-1"><!-- --></div>
#  <div class="ember-view" id="artdeco-gen-73"><div class="ember-view" id="ember773"></div></div>
#  </span>
#  <div>
#  <!-- -->
#  </div>
#  <!-- -->
#  <!-- --></div>
#  <div class="feed-shared-social-action-bar__action-button">
#  <span class="artdeco-hoverable-trigger artdeco-hoverable-trigger--content-placed-top artdeco-hoverable-trigger--is-hoverable ember-view" id="ember774" tabindex="-1">
#  <button aria-label="Enviar em mensagem privada" class="social-actions-button send-privately-button artdeco-button artdeco-button--4 artdeco-button--tertiary flex-wrap artdeco-button--muted send-privately-button" data-finite-scroll-hotkey="s" type="button">
#  <svg aria-hidden="true" class="rtl-flip" data-supported-dps="24x24" data-test-icon="send-privately-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#send-privately-medium" width="24"></use>
#  </svg>
#  <span class="artdeco-button__text social-action-button__text">Enviar</span>
#  </button>
#  <div class="ember-view" id="artdeco-gen-74"><div class="ember-view" id="ember776"></div></div>
#  </span>
#  </div>
#  </div>
#  <!-- --><!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <span aria-label="" aria-live="polite" class="visually-hidden" role="alert"></span>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="feed-shared-update-v2__comments-container display-flex flex-column">
#  <!-- --><!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <div class="ember-view" id="ember778"><!-- --></div>
#  <!-- -->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- -->
#  </div>]
